# %% [markdown]
# # 🛰️ CONPLANOS - V5
# Herramientas GNSS + Generador de data + Certificado.

# %%
# !pip -q install streamlit>=1.40,<2 PyMuPDF>=1.24,<2 openpyxl>=3.1,<4 python-docx>=1.1,<2 reportlab>=4.0,<5 Pillow>=10,<12

# %% [markdown]
# ## Sube aquí el ZIP V5 y descomprímelo

# %%
from google.colab import files
uploaded = files.upload()
import zipfile, io, os
zip_name = next(iter(uploaded))
with zipfile.ZipFile(io.BytesIO(uploaded[zip_name])) as z:
    z.extractall('/content/conplanos_v5')
print('Archivos extraídos en /content/conplanos_v5')

# %% [markdown]
# ## Ejecutar Streamlit

# %%
# !streamlit run /content/conplanos_v5/app.py --server.headless true --server.port 8501 > /content/streamlit.log 2>&1 &
# !npx --yes localtunnel --port 8501
